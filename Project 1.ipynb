# %%
# %run "Solution/Task1.py"

# %%
# %run "Solution/Task2.py"
# Out:
#                         Lists       Mean
# 0     Healthcare and Medicine  53.640867
# 1               Law and Legal  53.186175
# 2    Health and Mental Health  51.392411
# 3        Science and Research  50.642774
# 4             Design and Arts  50.349946
# 5         Film and Television  49.991307
# 6                   Education  49.897373
# 7  Technology and Engineering  49.795184
# 8      Finance and Accounting  49.440629
#                                 Job       Mean                       Lists
# 0               Trade mark attorney  73.802727        Science and Research
# 1                        Translator  70.777647  Technology and Engineering
# 2                Investment analyst  69.090000      Finance and Accounting
# 3  Accountant, chartered management  69.082667  Technology and Engineering
# 4      Designer, industrial/product  68.714667             Design and Arts

# %%
# %run "Solution/Task3.py"
# Out:
#   Platform  Purchase Frequency
# 0  Desktop                9377
# 1   Mobile                 623
#   Browser Info  Purchase Frequency
# 0      Mozilla                7301
# 1        Opera                2076
#   Browser Info  Purchase Frequency
# 0      Mozilla                 623

# %%
# %run "Solution/Task4.py"
# Out:
#                        Region  Purchase Price
# 0                       South            2274
# 1                     Midwest            1854
# 2                    National            1538
# 3  Hawaii and Pacific Islands            1401
# 4                   Northeast            1379
# 5           Pacific Northwest             897
# 6                   Southwest             852
# 7                     Central             306
#                         Region AM or PM  Purchase Price
# 0                        South       AM            1142
# 1                        South       PM            1132
# 2                      Midwest       AM             933
# 3                      Midwest       PM             921
# 4                     National       AM             776
# 5                     National       PM             762
# 6   Hawaii and Pacific Islands       PM             728
# 7                    Northeast       PM             711
# ...

# %%
# %run "Solution/Task5.py"
# Out:
#                    CC Provider  Purchase Frequency
# 0                          JCB                2584
# 1                         VISA                2492
# 2             American Express                 849
# 3                      Maestro                 846
# 4                      Voyager                 829
# 5                     Discover                 817
# 6                   Mastercard                 816
# 7  Diners Club / Carte Blanche                 767
#                     CC Provider AM or PM  Purchase Frequency
# 0                           JCB       PM                1294
# 1                           JCB       AM                1290
# 2                          VISA       PM                1247
# 3                          VISA       AM                1245
# 4                       Maestro       PM                 454
# 5                    Mastercard       PM                 438
# 6              American Express       AM                 428
# ...
